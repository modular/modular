# %%
# %%mojo
#
# fn hello(mut arg: String):
#     if len(arg):
#         arg = arg + "\n"
#     arg = arg + "Hello, World!"

# %%
a = String()
print(a)
hello(a)
print(a)
hello(a)
print(type(a))
b = repr(a)
print(type(b))
